# %%
# !pip install roboflow
# Out:
# Collecting roboflow
#   Downloading roboflow-1.2.11-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from roboflow) (2025.10.5)
# Collecting idna==3.7 (from roboflow)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from roboflow) (3.10.7)
# Requirement already satisfied: numpy>=1.18.5 in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from roboflow) (2.2.6)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from roboflow) (12.0.0)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.1.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.2-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: python-dateutil in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from roboflow) (2.5.0)
# Collecting tqdm>=4.41.0 (from roboflow)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from roboflow) (6.0.3)
# Collecting requests-toolbelt (from roboflow)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from matplotlib->roboflow) (4.60.1)
# Requirement already satisfied: packaging>=20.0 in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=3 in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from matplotlib->roboflow) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/hinfinity/miniconda3/envs/diplomado_robotica/lib/python3.13/site-packages (from requests->roboflow) (3.4.4)
# Downloading roboflow-1.2.11-py3-none-any.whl (89 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
# Downloading pi_heif-1.1.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 2.6 MB/s  0:00:00 eta 0:00:01
# Downloading pillow_avif_plugin-1.5.2-cp313-cp313-manylinux_2_28_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 4.2 MB/s  0:00:00 eta 0:00:01m
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: pillow-avif-plugin, filetype, tqdm, python-dotenv, pi-heif, opencv-python-headless, idna, requests-toolbelt, roboflow
#   Attempting uninstall: idna━━╺━━━━━━━━━━━━━━━━━ 5/9 [opencv-python-headless]
#     Found existing installation: idna 3.1190m━━━━━━━━━━━━━━━━━ 5/9 [opencv-python-headless]
#     Uninstalling idna-3.11:╺━━━━━━━━━━━━━━━━━ 5/9 [opencv-python-headless]
#       Successfully uninstalled idna-3.11━━━━━━━━━━━━━━━━━ 5/9 [opencv-python-headless]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [roboflow]8/9 [roboflow]toolbelt]]
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.1.1 pillow-avif-plugin-1.5.2 python-dotenv-1.1.1 requests-toolbelt-1.0.0 roboflow-1.2.11 tqdm-4.67.1

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="URvuFv8cg0qV3S6gTyWM")
project = rf.workspace("bolivianlprauzaetal").project("bolivian_lpr-_augmented_fixed-yop0m")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Bolivian_LPR-_Augmented_Fixed-2 to yolov11:: 100%|██████████| 161785/161785 [00:19<00:00, 8235.46it/s]
# Extracting Dataset Version Zip to Bolivian_LPR-_Augmented_Fixed-2 in yolov11:: 100%|██████████| 2760/2760 [00:00<00:00, 5631.10it/s]
