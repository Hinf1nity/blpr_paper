# %%
# !pip install roboflow
# Out:
# Collecting roboflow
#   Downloading roboflow-1.2.11-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /home/hinfinity/miniconda3/envs/blpr/lib/python3.14/site-packages (from roboflow) (2025.11.12)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /home/hinfinity/miniconda3/envs/blpr/lib/python3.14/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/hinfinity/miniconda3/envs/blpr/lib/python3.14/site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /home/hinfinity/miniconda3/envs/blpr/lib/python3.14/site-packages (from roboflow) (3.10.7)
# Requirement already satisfied: numpy>=1.18.5 in /home/hinfinity/miniconda3/envs/blpr/lib/python3.14/site-packages (from roboflow) (2.2.6)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /home/hinfinity/miniconda3/envs/blpr/lib/python3.14/site-packages (from roboflow) (11.3.0)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.1.1-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.2.tar.gz (20 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       Traceback (most recent call last):
#         File "/home/hinfinity/miniconda3/envs/blpr/lib/python3.14/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 389, in <module>
#           main()
#           ~~~~^^
#         File "/home/hinfinity/miniconda3/envs/blpr/lib/python3.14/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/hinfinity/miniconda3/envs/blpr/lib/python3.14/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 143, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "/tmp/pip-build-env-h5b2frs4/overlay/lib/python3.14/site-packages/setuptools/build_meta.py", line 331, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/tmp/pip-build-env-h5b2frs4/overlay/lib/python3.14/site-packages/setuptools/build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#           ~~~~~~~~~~~~~~^^
#         File "/tmp/pip-build-env-h5b2frs4/overlay/lib/python3.14/site-packages/setuptools/build_meta.py", line 317, in run_setup
#           exec(code, locals())
#           ~~~~^^^^^^^^^^^^^^^^
#         File "<string>", line 57, in <module>
#         File "<string>", line 17, in version
#       AttributeError: 'Constant' object has no attribute 's'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'pillow-avif-plugin' when getting requirements to build wheel

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="URvuFv8cg0qV3S6gTyWM")
project = rf.workspace("bolivianlprauzaetal").project("bolivian_lpr-_augmented_fixed-yop0m")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Bolivian_LPR-_Augmented_Fixed-2 to yolov11:: 100%|██████████| 161785/161785 [00:19<00:00, 8235.46it/s]
# Extracting Dataset Version Zip to Bolivian_LPR-_Augmented_Fixed-2 in yolov11:: 100%|██████████| 2760/2760 [00:00<00:00, 5631.10it/s]
