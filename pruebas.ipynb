# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="URvuFv8cg0qV3S6gTyWM")
project = rf.workspace("bolivianlprauzaetal").project("bolivian_lpr-_augmented_fixed-yop0m")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Bolivian_LPR-_Augmented_Fixed-1 in yolov8:: 100%|██████████| 2030/2030 [00:00<00:00, 6232.71it/s]
