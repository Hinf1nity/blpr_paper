# %%
from ollama import chat
from ollama import ChatResponse, ps

# %%
img_path = "tests/Test_Model_3.jpeg"
response: ChatResponse = chat(model='gemma3:4b-it-qat', messages=[
  {
    'role': 'user',
    'content': 'Read the plates from the image:',
    'images': [img_path],
  },
])
print(response['message']['content'])
# Out:
# Here's the license plate number from the image:
#
# **347706X**

# %%
img_path = "tests/Test_Model_1.jpeg"
response: ChatResponse = chat(model='gemma3:4b', messages=[
  {
    'role': 'user',
    'content': 'Read the plates from the image:',
    'images': [img_path],
  },
])
print(response['message']['content'])
# Out:
# Here's the text from the license plates in the image:
#
# *   **Blue car:** 5280 YIN
# *   **Gray car:** 242NKH
